# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.parser import parse

# %%
hotel_df = pd.read_csv('C:/hotel_bookings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-60fd479f01b9> in <module>()
# ----> 1 hotel_df = pd.read_csv('C:/hotel_bookings.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# 결측치 확인 - children, country, agent, company 결측치 존재.
hotel_df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# 특성 삭제 - arrival_date_week_number, hotel, distribution_channel, company데이터 셋 삭제.
hotel_df = hotel_df.drop(['arrival_date_week_number', 'distribution_channel', 'company'], axis = 1)

# %%
# 특성 대치 - children, agent, country
hotel_df['children'] = hotel_df['children'].fillna(0)
hotel_df['agent'] = hotel_df['agent'].fillna(-1)
hotel_df['country'] = hotel_df['country'].fillna('undefined')

# %%
# 결측치 제거 완료.
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_day_of_month       119390 non-null  int64
#  6   stays_in_weekend_nights         119390 non-null  int64
#  7   stays_in_week_nights            119390 non-null  int64
#  8   adults                          119390 non-null  int64
#  9   children                        119390 non-null  float64
#  10  babies                          119390 non-null  int64
#  11  meal                            119390 non-null  object
# ...

# %%
# "arrival_date_month" 데이터를 숫자 형태로 바꾸기.

datetime_object = hotel_df['arrival_date_month'].str[0:3]
month_number = np.zeros(len(datetime_object))

for i in range(0, len(datetime_object)):
    datetime_object[i] = datetime.strptime(datetime_object[i], "%b")
    month_number[i] = datetime_object[i].month

# Float to integer conversion
month_number = pd.DataFrame(month_number).astype(int)

# %%
# 'arrival date' 컬럼 생성(연-월-일 날짜 형식으로 변환한 컬럼.)
hotel_df['arrival_date'] = hotel_df['arrival_date_year'].map(str) + '-' + month_number[0].map(str) + '-' \
                       + hotel_df['arrival_date_day_of_month'].map(str)

# %%
# dateutill parse 사용해서 데이터 형식 바꿔놨음.

# %%
# hotel_df['arrival_date'][0]
#'2015-7-1'
# Out:
# '2015-7-1'

# %%
# 바꾼 과정은... 날아갔둠...
hotel_df['arrival_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-01
# 3        2015-07-01
# 4        2015-07-01
#             ...
# 119385   2015-07-01
# 119386   2015-07-01
# 119387   2015-07-01
# 119388   2015-07-01
# 119389   2015-07-01
# Name: arrival_date, Length: 119390, dtype: datetime64[ns]

# %%
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                    July                          1                        0
# ...

# %%
# 연, 월, 일 데이터 삭제.
# hotel_df = hotel_df.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month'], axis=1)
# hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0  Resort Hotel            0        342                        0
# 1  Resort Hotel            0        737                        0
# 2  Resort Hotel            0          7                        0
# 3  Resort Hotel            0         13                        0
# 4  Resort Hotel            0         14                        0
#
#    stays_in_week_nights  adults  children  babies meal country  ...  \
# 0                     0       2       0.0       0   BB     PRT  ...
# 1                     0       2       0.0       0   BB     PRT  ...
# 2                     1       1       0.0       0   BB     GBR  ...
# 3                     1       1       0.0       0   BB     GBR  ...
# 4                     2       2       0.0       0   BB     GBR  ...
#
#   deposit_type  agent  days_in_waiting_list  customer_type   adr  \
# 0   No Deposit   -1.0                     0      Transient   0.0
# ...

# %%
# arrival date 데이터 형식 조정
hotel_df['arrival_date'] = pd.to_datetime(hotel_df['arrival_date'])

print('Datatype of the arrival_date:', hotel_df['arrival_date'].dtype)
print('Datatype of the reservation_status_date:', hotel_df['reservation_status_date'].dtype)
# Out:
# Datatype of the arrival_date: datetime64[ns]
# Datatype of the reservation_status_date: datetime64[ns]

# %%
hotel_df['total_guests'] = hotel_df['adults'] + hotel_df['children']
hotel_df['total_guests'].head(10)
# Out:
# 0    2.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    2.0
# 5    2.0
# 6    2.0
# 7    2.0
# 8    2.0
# 9    2.0
# Name: total_guests, dtype: float64

# %%
hotel_df['total_guests'].unique()
# Out:
# array([ 2.,  1.,  3.,  4.,  5., 12., 40., 26., 50., 27., 55., 20.,  6.,
#        10.])

# %%
# 전체 객수가 0명인 데이터 삭제.
hotel_df = hotel_df[hotel_df['total_guests'] != 0]

# %%
# 객수 0명 데이터 확인.
hotel_df['total_guests'].unique()
# Out:
# array([ 2.,  1.,  3.,  4.,  5., 12., 40., 26., 50., 27., 55., 20.,  6.,
#        10.])

# %%
# 총 숙박일수 'Total_Stays'
hotel_df['total_stays'] = hotel_df['stays_in_weekend_nights'] + hotel_df['stays_in_week_nights']

# %%
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                    July                          1                        0
# ...

# %%
hotel_df['total_rate'] = hotel_df['total_stays'] * hotel_df['adr']

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119210 entries, 0 to 119389
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119210 non-null  object
#  1   is_canceled                     119210 non-null  int64
#  2   lead_time                       119210 non-null  int64
#  3   arrival_date_year               119210 non-null  int64
#  4   arrival_date_month              119210 non-null  object
#  5   arrival_date_day_of_month       119210 non-null  int64
#  6   stays_in_weekend_nights         119210 non-null  int64
#  7   stays_in_week_nights            119210 non-null  int64
#  8   adults                          119210 non-null  int64
#  9   children                        119210 non-null  float64
#  10  babies                          119210 non-null  int64
#  11  meal                            119210 non-null  object
# ...

# %%
# 전처리된 데이터 저장.
hotel_df.to_csv("hotel_df_booking_predict.csv", index = False)

# %%
# https://www.kaggle.com/atasaygin/hotel-booking-demand-eda-and-of-guest-prediction#Data-Cleaning
# https://www.kaggle.com/duygut/eda-booking-cancelation-prediction#2.-Dealing-with-Missing-Data-and-Correlation-Matrix
